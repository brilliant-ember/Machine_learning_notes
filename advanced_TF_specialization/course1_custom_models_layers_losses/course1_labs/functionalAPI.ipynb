# %%
# https://github.com/shreyasvedpathak/Tensorflow-Advanced-Techniques-Solutions/blob/main/Course%201/Week1_Assignment.ipynb

import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Input

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
import itertools
import os

import utils # this is for unit tests, note that some don't work unless you paste the test in the same cell (eager excecution?)

# %%
path_base = '../dataset/quality/'
white_ds = path_base + 'white.csv'
red_ds = path_base + 'red.csv'


white_ds = pd.read_csv(white_ds, sep=";")
red_ds = pd.read_csv(red_ds, sep=";")

# %%
red_ds
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 5               7.4             0.660         0.00             1.8      0.075
# ...             ...               ...          ...             ...        ...
# 1593            6.8             0.620         0.08             1.9      0.068
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0  0.99680  3.20       0.68
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 3                    17.0                  60.0  0.99800  3.16       0.58
# 5                    13.0                  40.0  0.99780  3.51       0.56
# ...                   ...                   ...      ...   ...        ...
# 1593                 28.0                  38.0  0.99651  3.42       0.82
# 1594                 32.0                  44.0  0.99490  3.45       0.58
# 1595                 39.0                  51.0  0.99512  3.52       0.76
# 1597                 32.0                  44.0  0.99547  3.57       0.71
# 1598                 18.0                  42.0  0.99549  3.39       0.66
#
#       alcohol  quality  is_red
# 0         9.4        5       1
# 1         9.8        5       1
# 2         9.8        5       1
# 3         9.8        6       1
# 5         9.4        5       1
# ...       ...      ...     ...
# 1593      9.5        6       1
# 1594     10.5        5       1
# 1595     11.2        6       1
# 1597     10.2        5       1
# 1598     11.0        6       1
#
# [1359 rows x 13 columns]

# %%
# fill the `is_red` column with zeros.
white_ds["is_red"] = 0

white_ds = white_ds.drop_duplicates()
red_ds = red_ds.drop_duplicates()
utils.test_white_df(white_ds)
# Out:
#  All public tests passed

# %%
print(white_ds.alcohol[0])
print(white_ds.alcohol[100])
# EXPECTED OUTPUT
# 8.8
# 9.1
# Out:
# 8.8
# 9.1

# %%
red_ds["is_red"] = 1
utils.test_red_df(red_ds)
# Out:
#  All public tests passed

# %%
print(red_ds.alcohol[0])
print(red_ds.alcohol[100])

# EXPECTED OUTPUT
# 9.4
# 10.2
# Out:
# 9.4
# 10.2

# %%
white_ds.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    3961.000000       3961.000000  3961.000000     3961.000000
# mean        6.839346          0.280538     0.334332        5.914819
# std         0.866860          0.103437     0.122446        4.861646
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.300000          0.210000     0.270000        1.600000
# 50%         6.800000          0.260000     0.320000        4.700000
# 75%         7.300000          0.330000     0.390000        8.900000
# max        14.200000          1.100000     1.660000       65.800000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  3961.000000          3961.000000           3961.000000  3961.000000
# mean      0.045905            34.889169            137.193512     0.993790
# std       0.023103            17.210021             43.129065     0.002905
# min       0.009000             2.000000              9.000000     0.987110
# 25%       0.035000            23.000000            106.000000     0.991620
# 50%       0.042000            33.000000            133.000000     0.993500
# 75%       0.050000            45.000000            166.000000     0.995710
# max       0.346000           289.000000            440.000000     1.038980
#
#                 pH    sulphates      alcohol      quality  is_red
# count  3961.000000  3961.000000  3961.000000  3961.000000  3961.0
# mean      3.195458     0.490351    10.589358     5.854835     0.0
# std       0.151546     0.113523     1.217076     0.890683     0.0
# min       2.720000     0.220000     8.000000     3.000000     0.0
# 25%       3.090000     0.410000     9.500000     5.000000     0.0
# 50%       3.180000     0.480000    10.400000     6.000000     0.0
# 75%       3.290000     0.550000    11.400000     6.000000     0.0
# max       3.820000     1.080000    14.200000     9.000000     0.0

# %%
red_ds.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1359.000000       1359.000000  1359.000000     1359.000000
# mean        8.310596          0.529478     0.272333        2.523400
# std         1.736990          0.183031     0.195537        1.352314
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.430000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1359.000000          1359.000000           1359.000000  1359.000000
# mean      0.088124            15.893304             46.825975     0.996709
# std       0.049377            10.447270             33.408946     0.001869
# min       0.012000             1.000000              6.000000     0.990070
# 25%       0.070000             7.000000             22.000000     0.995600
# 50%       0.079000            14.000000             38.000000     0.996700
# 75%       0.091000            21.000000             63.000000     0.997820
# max       0.611000            72.000000            289.000000     1.003690
#
#                 pH    sulphates      alcohol      quality  is_red
# count  1359.000000  1359.000000  1359.000000  1359.000000  1359.0
# mean      3.309787     0.658705    10.432315     5.623252     1.0
# std       0.155036     0.170667     1.082065     0.823578     0.0
# min       2.740000     0.330000     8.400000     3.000000     1.0
# 25%       3.210000     0.550000     9.500000     5.000000     1.0
# 50%       3.310000     0.620000    10.200000     6.000000     1.0
# 75%       3.400000     0.730000    11.100000     6.000000     1.0
# max       4.010000     2.000000    14.900000     8.000000     1.0

# %%
ds = pd.concat([red_ds, white_ds], ignore_index=True)
ds.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    5320.000000       5320.000000  5320.000000     5320.000000
# mean        7.215179          0.344130     0.318494        5.048477
# std         1.319671          0.168248     0.147157        4.500180
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.400000          0.230000     0.240000        1.800000
# 50%         7.000000          0.300000     0.310000        2.700000
# 75%         7.700000          0.410000     0.400000        7.500000
# max        15.900000          1.580000     1.660000       65.800000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  5320.000000          5320.000000           5320.000000  5320.000000
# mean      0.056690            30.036654            114.109023     0.994535
# std       0.036863            17.805045             56.774223     0.002966
# min       0.009000             1.000000              6.000000     0.987110
# 25%       0.038000            16.000000             74.000000     0.992200
# 50%       0.047000            28.000000            116.000000     0.994650
# 75%       0.066000            41.000000            153.250000     0.996770
# max       0.611000           289.000000            440.000000     1.038980
#
#                 pH    sulphates      alcohol      quality       is_red
# count  5320.000000  5320.000000  5320.000000  5320.000000  5320.000000
# mean      3.224664     0.533357    10.549241     5.795677     0.255451
# std       0.160379     0.149743     1.185933     0.879772     0.436155
# min       2.720000     0.220000     8.000000     3.000000     0.000000
# 25%       3.110000     0.430000     9.500000     5.000000     0.000000
# 50%       3.210000     0.510000    10.400000     6.000000     0.000000
# 75%       3.330000     0.600000    11.400000     6.000000     1.000000
# max       4.010000     2.000000    14.900000     9.000000     1.000000

# %%
# NOTE: In a real-world scenario, you should shuffle the data.
# YOU ARE NOT going to do that here because we want to test
# with deterministic data. But if you want the code to do it,
# it's in the commented line below:

#df = df.iloc[np.random.permutation(len(df))]

# %%
ds['quality'].hist(bins=20);

# %%
# comme tu veux il n y a pas beaucoup de data dans quality
# 3,4,8,9 pour cette reason nous allons delete ces columns

ds = ds[(ds['quality'] > 4) & (ds['quality'] < 8 )]
ds = ds.reset_index(drop=True)

# %%
ds['quality'].hist(bins=20);

# %%
utils.test_df_drop(ds)
# Out:
#  All public tests passed

# %%
# split df into 80:20 train and test sets
train, test = train_test_split(ds, test_size=0.2, random_state = 1)
                               
# split train into 80:20 train and val sets
train, val = train_test_split(train, test_size=0.2, random_state = 1)

utils.test_data_sizes(train.size, test.size, val.size)
# Out:
#  All public tests passed

# %%
train_stats = train.describe()
train_stats.pop('is_red') # label
train_stats.pop('quality') #label
train_stats = train_stats.transpose()
train_stats
# Out:
#                        count        mean        std      min       25%  \
# fixed acidity         3155.0    7.221616   1.325297  3.80000   6.40000
# volatile acidity      3155.0    0.338929   0.162476  0.08000   0.23000
# citric acid           3155.0    0.321569   0.147970  0.00000   0.25000
# residual sugar        3155.0    5.155911   4.639632  0.60000   1.80000
# chlorides             3155.0    0.056976   0.036802  0.01200   0.03800
# free sulfur dioxide   3155.0   30.388590  17.236784  1.00000  17.00000
# total sulfur dioxide  3155.0  115.062282  56.706617  6.00000  75.00000
# density               3155.0    0.994633   0.003005  0.98711   0.99232
# pH                    3155.0    3.223201   0.161272  2.72000   3.11000
# sulphates             3155.0    0.534051   0.149149  0.22000   0.43000
# alcohol               3155.0   10.504466   1.154654  8.50000   9.50000
#
#                             50%       75%        max
# fixed acidity           7.00000    7.7000   15.60000
# volatile acidity        0.29000    0.4000    1.24000
# citric acid             0.31000    0.4000    1.66000
# residual sugar          2.80000    7.6500   65.80000
# chlorides               0.04700    0.0660    0.61100
# free sulfur dioxide    28.00000   41.0000  131.00000
# total sulfur dioxide  117.00000  156.0000  344.00000
# density                 0.99481    0.9968    1.03898
# pH                      3.21000    3.3300    4.01000
# sulphates               0.51000    0.6000    1.95000
# alcohol                10.30000   11.3000   14.00000

# %%
def format_output(data):
    '''this function doubles as removing the label form the train ds
    and for getting the labels as output, the pop
    function changes the original input data, therefore we do remove
    the label cols out of the input ds'''
    is_red = data.pop('is_red') #pop function removed it for good from the input dataframe
    is_red = np.array(is_red)
    quality = data.pop('quality')
    quality = np.array(quality)
    return (quality, is_red)

# %%
# format the output of the train set
train_Y = format_output(train)

# format the output of the val set
val_Y = format_output(val)
    
# format the output of the test set
test_Y = format_output(test)

# %%
utils.test_format_output(ds, train_Y, val_Y, test_Y)
# Out:
#  All public tests passed

# %%
train.head()
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 225             7.5              0.65         0.18             7.0      0.088
# 3557            6.3              0.27         0.29            12.2      0.044
# 3825            8.8              0.27         0.25             5.0      0.024
# 1740            6.4              0.45         0.07             1.1      0.030
# 1221            7.2              0.53         0.13             2.0      0.058
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 225                  27.0                  94.0  0.99915  3.38       0.77
# 3557                 59.0                 196.0  0.99782  3.14       0.40
# 3825                 52.0                  99.0  0.99250  2.87       0.49
# 1740                 10.0                 131.0  0.99050  2.97       0.28
# 1221                 18.0                  22.0  0.99573  3.21       0.68
#
#       alcohol
# 225       9.4
# 3557      8.8
# 3825     11.4
# 1740     10.8
# 1221      9.9

# %%
def norm(x):
    '''data normalization formula'''
    return (x - train_stats['mean']) / train_stats['std']

# normalize the train set
norm_train_X = norm(train)
    
# normalize the val set
norm_val_X = norm(val)
    
# normalize the test set
norm_test_X = norm(test)

utils.test_norm(norm_train_X, norm_val_X, norm_test_X, train, val, test)
# Out:
#  All public tests passed

# %%
def base_model(inputs):
    
    # connect a Dense layer with 128 neurons and a relu activation
    x = Dense(units=128, activation='relu')(inputs)
    
    # connect another Dense layer with 128 neurons and a relu activation
    x = Dense(units=128, activation='relu')(x)
    return x

utils.test_base_model(base_model)
# test_inputs = tf.keras.layers.Input(shape=(11,))
# test_output = base_model(test_inputs)
# test_model = Model(inputs=test_inputs, outputs=test_output)
# type(test_model.layers[-1]) == Dense
# Out:
# return_type_check: Return type is incorrect. Please check implementation.
# Expected: <class 'tensorflow.python.framework.ops.Tensor'>
# Result: <class 'keras.engine.keras_tensor.KerasTensor'>
# Please open utils.py if you want to see the unit test here.
#
#  5  Tests passed
#  1  Tests failed
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-22-fef4ec628f01> in <module>
#       8     return x
#       9
# ---> 10 utils.test_base_model(base_model)
#      11 # test_inputs = tf.keras.layers.Input(shape=(11,))
#      12 # test_output = base_model(test_inputs)
#
# ~/Documents/myGithub/Machine_learning_notes/advanced_TF_specialization/course_1_labs/utils.py in test_base_model(base_model)
#     260     ]
#     261
# --> 262     test_loop(test_cases)
#     263
#     264 def test_final_model(final_model):
#
# ~/Documents/myGithub/Machine_learning_notes/advanced_TF_specialization/course_1_labs/utils.py in test_loop(test_cases)
#      28         print('\033', success," Tests passed")
#      29         print('\033', fails, " Tests failed")
# ---> 30         raise Exception(test_case["error_message"])
#      31
#      32 def test_white_df(white_df):
#
# Exception: Output layer type is incorrect. Please check implementation.

# %%
# we will define two outputs
# the first one is a linear regression of the quality
# the second is a classification if whether it is red or white
# in the second case since it is a linear problem we don't need to add a non-linearity 
# since a linear model will be enough we will not add a non-linear activation function
# and we will settle with the linear coffienets (weights) the model will output for the regression

def final_model(inputs):
    x = base_model(inputs)
    # 1 unit(neuron) becaue we need a single number for quality
    quality_regression = Dense(units=1, name="quality_regression")(x)
    # 1 unit since it is a binary classifcation, 1 or 0 kinda thing, either red or not
    is_red_classification = Dense(units=1, activation="sigmoid", name='type_classifcation')(x)
    
    return Model(inputs=[inputs], outputs=[quality_regression, is_red_classification])


# utils.test_final_model(final_model) # ignore failure

# %%
inputs = tf.keras.layers.Input(shape=(11,))
rms = tf.keras.optimizers.RMSprop(learning_rate=0.0001)
model = final_model(inputs)
model.compile(
    optimizer=rms, loss={'type_classifcation':'binary_crossentropy', 'quality_regression':'mse'}, 
    metrics = {'type_classifcation': 'accuracy', 'quality_regression': tf.keras.metrics.RootMeanSquaredError()}
             )
model.metrics
# Out:
# []

# %%
# utils.test_model_compile(model) #empty metrics is a known bug, will fix itself after fitting

# %%
history = model.fit(norm_train_X, train_Y,
                    epochs = 180, validation_data=(norm_val_X, val_Y))
# Out:
# Epoch 1/180
# 99/99 [==============================] - 2s 5ms/step - loss: 22.4026 - quality_regression_loss: 21.7151 - type_classifcation_loss: 0.6875 - quality_regression_root_mean_squared_error: 4.6599 - type_classifcation_accuracy: 0.5436 - val_loss: 15.4466 - val_quality_regression_loss: 14.7756 - val_type_classifcation_loss: 0.6710 - val_quality_regression_root_mean_squared_error: 3.8439 - val_type_classifcation_accuracy: 0.6324
# Epoch 2/180
# 99/99 [==============================] - 0s 4ms/step - loss: 10.0495 - quality_regression_loss: 9.4179 - type_classifcation_loss: 0.6317 - quality_regression_root_mean_squared_error: 3.0689 - type_classifcation_accuracy: 0.7315 - val_loss: 5.8082 - val_quality_regression_loss: 5.2128 - val_type_classifcation_loss: 0.5954 - val_quality_regression_root_mean_squared_error: 2.2832 - val_type_classifcation_accuracy: 0.7541
# Epoch 3/180
# 99/99 [==============================] - 0s 4ms/step - loss: 4.1352 - quality_regression_loss: 3.6023 - type_classifcation_loss: 0.5329 - quality_regression_root_mean_squared_error: 1.8980 - type_classifcation_accuracy: 0.7756 - val_loss: 2.8655 - val_quality_regression_loss: 2.3867 - val_type_classifcation_loss: 0.4787 - val_quality_regression_root_mean_squared_error: 1.5449 - val_type_classifcation_accuracy: 0.7909
# Epoch 4/180
# 99/99 [==============================] - 0s 4ms/step - loss: 2.6409 - quality_regression_loss: 2.2283 - type_classifcation_loss: 0.4125 - quality_regression_root_mean_squared_error: 1.4928 - type_classifcation_accuracy: 0.8365 - val_loss: 2.3135 - val_quality_regression_loss: 1.9485 - val_type_classifcation_loss: 0.3651 - val_quality_regression_root_mean_squared_error: 1.3959 - val_type_classifcation_accuracy: 0.8986
# Epoch 5/180
# 99/99 [==============================] - 0s 3ms/step - loss: 2.2034 - quality_regression_loss: 1.8901 - type_classifcation_loss: 0.3133 - quality_regression_root_mean_squared_error: 1.3748 - type_classifcation_accuracy: 0.9353 - val_loss: 2.0324 - val_quality_regression_loss: 1.7546 - val_type_classifcation_loss: 0.2778 - val_quality_regression_root_mean_squared_error: 1.3246 - val_type_classifcation_accuracy: 0.9556
# Epoch 6/180
# 99/99 [==============================] - 0s 4ms/step - loss: 1.9303 - quality_regression_loss: 1.6912 - type_classifcation_loss: 0.2391 - quality_regression_root_mean_squared_error: 1.3004 - type_classifcation_accuracy: 0.9689 - val_loss: 1.7962 - val_quality_regression_loss: 1.5848 - val_type_classifcation_loss: 0.2114 - val_quality_regression_root_mean_squared_error: 1.2589 - val_type_classifcation_accuracy: 0.9785
# Epoch 7/180
# 99/99 [==============================] - 0s 4ms/step - loss: 1.7214 - quality_regression_loss: 1.5394 - type_classifcation_loss: 0.1820 - quality_regression_root_mean_squared_error: 1.2407 - type_classifcation_accuracy: 0.9832 - val_loss: 1.6254 - val_quality_regression_loss: 1.4634 - val_type_classifcation_loss: 0.1620 - val_quality_regression_root_mean_squared_error: 1.2097 - val_type_classifcation_accuracy: 0.9835
# Epoch 8/180
# 99/99 [==============================] - 0s 4ms/step - loss: 1.5664 - quality_regression_loss: 1.4228 - type_classifcation_loss: 0.1436 - quality_regression_root_mean_squared_error: 1.1928 - type_classifcation_accuracy: 0.9851 - val_loss: 1.4782 - val_quality_regression_loss: 1.3511 - val_type_classifcation_loss: 0.1271 - val_quality_regression_root_mean_squared_error: 1.1624 - val_type_classifcation_accuracy: 0.9848
# Epoch 9/180
# 99/99 [==============================] - 0s 3ms/step - loss: 1.4353 - quality_regression_loss: 1.3207 - type_classifcation_loss: 0.1146 - quality_regression_root_mean_squared_error: 1.1492 - type_classifcation_accuracy: 0.9870 - val_loss: 1.3571 - val_quality_regression_loss: 1.2544 - val_type_classifcation_loss: 0.1027 - val_quality_regression_root_mean_squared_error: 1.1200 - val_type_classifcation_accuracy: 0.9861
# Epoch 10/180
# 99/99 [==============================] - 0s 4ms/step - loss: 1.3200 - quality_regression_loss: 1.2256 - type_classifcation_loss: 0.0944 - quality_regression_root_mean_squared_error: 1.1071 - type_classifcation_accuracy: 0.9889 - val_loss: 1.2567 - val_quality_regression_loss: 1.1717 - val_type_classifcation_loss: 0.0850 - val_quality_regression_root_mean_squared_error: 1.0824 - val_type_classifcation_accuracy: 0.9861
# Epoch 11/180
# 99/99 [==============================] - 0s 4ms/step - loss: 1.2266 - quality_regression_loss: 1.1459 - type_classifcation_loss: 0.0806 - quality_regression_root_mean_squared_error: 1.0705 - type_classifcation_accuracy: 0.9886 - val_loss: 1.1776 - val_quality_regression_loss: 1.1044 - val_type_classifcation_loss: 0.0732 - val_quality_regression_root_mean_squared_error: 1.0509 - val_type_classifcation_accuracy: 0.9873
# Epoch 12/180
# 99/99 [==============================] - 0s 4ms/step - loss: 1.1408 - quality_regression_loss: 1.0701 - type_classifcation_loss: 0.0707 - quality_regression_root_mean_squared_error: 1.0345 - type_classifcation_accuracy: 0.9902 - val_loss: 1.0999 - val_quality_regression_loss: 1.0358 - val_type_classifcation_loss: 0.0641 - val_quality_regression_root_mean_squared_error: 1.0178 - val_type_classifcation_accuracy: 0.9873
# Epoch 13/180
# 99/99 [==============================] - 0s 4ms/step - loss: 1.0666 - quality_regression_loss: 1.0035 - type_classifcation_loss: 0.0631 - quality_regression_root_mean_squared_error: 1.0018 - type_classifcation_accuracy: 0.9902 - val_loss: 1.0252 - val_quality_regression_loss: 0.9677 - val_type_classifcation_loss: 0.0575 - val_quality_regression_root_mean_squared_error: 0.9837 - val_type_classifcation_accuracy: 0.9873
# Epoch 14/180
# 99/99 [==============================] - 0s 4ms/step - loss: 0.9958 - quality_regression_loss: 0.9381 - type_classifcation_loss: 0.0577 - quality_regression_root_mean_squared_error: 0.9686 - type_classifcation_accuracy: 0.9905 - val_loss: 0.9617 - val_quality_regression_loss: 0.9093 - val_type_classifcation_loss: 0.0524 - val_quality_regression_root_mean_squared_error: 0.9536 - val_type_classifcation_accuracy: 0.9899
# Epoch 15/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.9327 - quality_regression_loss: 0.8793 - type_classifcation_loss: 0.0534 - quality_regression_root_mean_squared_error: 0.9377 - type_classifcation_accuracy: 0.9908 - val_loss: 0.9073 - val_quality_regression_loss: 0.8586 - val_type_classifcation_loss: 0.0487 - val_quality_regression_root_mean_squared_error: 0.9266 - val_type_classifcation_accuracy: 0.9911
# Epoch 16/180
# 99/99 [==============================] - 0s 4ms/step - loss: 0.8775 - quality_regression_loss: 0.8274 - type_classifcation_loss: 0.0501 - quality_regression_root_mean_squared_error: 0.9096 - type_classifcation_accuracy: 0.9908 - val_loss: 0.8549 - val_quality_regression_loss: 0.8089 - val_type_classifcation_loss: 0.0460 - val_quality_regression_root_mean_squared_error: 0.8994 - val_type_classifcation_accuracy: 0.9911
# Epoch 17/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.8287 - quality_regression_loss: 0.7811 - type_classifcation_loss: 0.0475 - quality_regression_root_mean_squared_error: 0.8838 - type_classifcation_accuracy: 0.9905 - val_loss: 0.8028 - val_quality_regression_loss: 0.7592 - val_type_classifcation_loss: 0.0436 - val_quality_regression_root_mean_squared_error: 0.8713 - val_type_classifcation_accuracy: 0.9911
# Epoch 18/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.7857 - quality_regression_loss: 0.7405 - type_classifcation_loss: 0.0452 - quality_regression_root_mean_squared_error: 0.8605 - type_classifcation_accuracy: 0.9908 - val_loss: 0.7567 - val_quality_regression_loss: 0.7151 - val_type_classifcation_loss: 0.0416 - val_quality_regression_root_mean_squared_error: 0.8457 - val_type_classifcation_accuracy: 0.9911
# Epoch 19/180
# 99/99 [==============================] - 0s 4ms/step - loss: 0.7416 - quality_regression_loss: 0.6982 - type_classifcation_loss: 0.0434 - quality_regression_root_mean_squared_error: 0.8356 - type_classifcation_accuracy: 0.9911 - val_loss: 0.7183 - val_quality_regression_loss: 0.6778 - val_type_classifcation_loss: 0.0405 - val_quality_regression_root_mean_squared_error: 0.8233 - val_type_classifcation_accuracy: 0.9911
# Epoch 20/180
# 99/99 [==============================] - 0s 4ms/step - loss: 0.6998 - quality_regression_loss: 0.6578 - type_classifcation_loss: 0.0420 - quality_regression_root_mean_squared_error: 0.8110 - type_classifcation_accuracy: 0.9914 - val_loss: 0.7022 - val_quality_regression_loss: 0.6636 - val_type_classifcation_loss: 0.0386 - val_quality_regression_root_mean_squared_error: 0.8146 - val_type_classifcation_accuracy: 0.9911
# Epoch 21/180
# 99/99 [==============================] - 0s 4ms/step - loss: 0.6660 - quality_regression_loss: 0.6253 - type_classifcation_loss: 0.0407 - quality_regression_root_mean_squared_error: 0.7908 - type_classifcation_accuracy: 0.9914 - val_loss: 0.6482 - val_quality_regression_loss: 0.6105 - val_type_classifcation_loss: 0.0377 - val_quality_regression_root_mean_squared_error: 0.7813 - val_type_classifcation_accuracy: 0.9911
# Epoch 22/180
# 99/99 [==============================] - 0s 4ms/step - loss: 0.6314 - quality_regression_loss: 0.5918 - type_classifcation_loss: 0.0396 - quality_regression_root_mean_squared_error: 0.7693 - type_classifcation_accuracy: 0.9924 - val_loss: 0.6177 - val_quality_regression_loss: 0.5811 - val_type_classifcation_loss: 0.0366 - val_quality_regression_root_mean_squared_error: 0.7623 - val_type_classifcation_accuracy: 0.9911
# Epoch 23/180
# 99/99 [==============================] - 0s 4ms/step - loss: 0.6036 - quality_regression_loss: 0.5650 - type_classifcation_loss: 0.0385 - quality_regression_root_mean_squared_error: 0.7517 - type_classifcation_accuracy: 0.9921 - val_loss: 0.5869 - val_quality_regression_loss: 0.5511 - val_type_classifcation_loss: 0.0359 - val_quality_regression_root_mean_squared_error: 0.7423 - val_type_classifcation_accuracy: 0.9911
# Epoch 24/180
# 99/99 [==============================] - 0s 4ms/step - loss: 0.5770 - quality_regression_loss: 0.5393 - type_classifcation_loss: 0.0377 - quality_regression_root_mean_squared_error: 0.7344 - type_classifcation_accuracy: 0.9918 - val_loss: 0.5620 - val_quality_regression_loss: 0.5265 - val_type_classifcation_loss: 0.0355 - val_quality_regression_root_mean_squared_error: 0.7256 - val_type_classifcation_accuracy: 0.9911
# Epoch 25/180
# 99/99 [==============================] - 0s 4ms/step - loss: 0.5510 - quality_regression_loss: 0.5140 - type_classifcation_loss: 0.0370 - quality_regression_root_mean_squared_error: 0.7170 - type_classifcation_accuracy: 0.9921 - val_loss: 0.5369 - val_quality_regression_loss: 0.5023 - val_type_classifcation_loss: 0.0347 - val_quality_regression_root_mean_squared_error: 0.7087 - val_type_classifcation_accuracy: 0.9911
# Epoch 26/180
# 99/99 [==============================] - 0s 4ms/step - loss: 0.5305 - quality_regression_loss: 0.4944 - type_classifcation_loss: 0.0362 - quality_regression_root_mean_squared_error: 0.7031 - type_classifcation_accuracy: 0.9921 - val_loss: 0.5154 - val_quality_regression_loss: 0.4811 - val_type_classifcation_loss: 0.0343 - val_quality_regression_root_mean_squared_error: 0.6936 - val_type_classifcation_accuracy: 0.9911
# Epoch 27/180
# 99/99 [==============================] - 0s 4ms/step - loss: 0.5124 - quality_regression_loss: 0.4768 - type_classifcation_loss: 0.0356 - quality_regression_root_mean_squared_error: 0.6905 - type_classifcation_accuracy: 0.9921 - val_loss: 0.5029 - val_quality_regression_loss: 0.4690 - val_type_classifcation_loss: 0.0339 - val_quality_regression_root_mean_squared_error: 0.6848 - val_type_classifcation_accuracy: 0.9924
# Epoch 28/180
# 99/99 [==============================] - 0s 4ms/step - loss: 0.4943 - quality_regression_loss: 0.4593 - type_classifcation_loss: 0.0350 - quality_regression_root_mean_squared_error: 0.6778 - type_classifcation_accuracy: 0.9927 - val_loss: 0.4844 - val_quality_regression_loss: 0.4510 - val_type_classifcation_loss: 0.0334 - val_quality_regression_root_mean_squared_error: 0.6715 - val_type_classifcation_accuracy: 0.9924
# Epoch 29/180
# 99/99 [==============================] - 0s 4ms/step - loss: 0.4769 - quality_regression_loss: 0.4424 - type_classifcation_loss: 0.0344 - quality_regression_root_mean_squared_error: 0.6652 - type_classifcation_accuracy: 0.9930 - val_loss: 0.4692 - val_quality_regression_loss: 0.4362 - val_type_classifcation_loss: 0.0330 - val_quality_regression_root_mean_squared_error: 0.6604 - val_type_classifcation_accuracy: 0.9924
# Epoch 30/180
# 99/99 [==============================] - 0s 4ms/step - loss: 0.4627 - quality_regression_loss: 0.4289 - type_classifcation_loss: 0.0338 - quality_regression_root_mean_squared_error: 0.6549 - type_classifcation_accuracy: 0.9930 - val_loss: 0.4598 - val_quality_regression_loss: 0.4271 - val_type_classifcation_loss: 0.0327 - val_quality_regression_root_mean_squared_error: 0.6535 - val_type_classifcation_accuracy: 0.9924
# Epoch 31/180
# 99/99 [==============================] - 0s 4ms/step - loss: 0.4509 - quality_regression_loss: 0.4175 - type_classifcation_loss: 0.0334 - quality_regression_root_mean_squared_error: 0.6462 - type_classifcation_accuracy: 0.9937 - val_loss: 0.4425 - val_quality_regression_loss: 0.4101 - val_type_classifcation_loss: 0.0324 - val_quality_regression_root_mean_squared_error: 0.6404 - val_type_classifcation_accuracy: 0.9924
# Epoch 32/180
# 99/99 [==============================] - 0s 4ms/step - loss: 0.4378 - quality_regression_loss: 0.4049 - type_classifcation_loss: 0.0329 - quality_regression_root_mean_squared_error: 0.6363 - type_classifcation_accuracy: 0.9933 - val_loss: 0.4434 - val_quality_regression_loss: 0.4114 - val_type_classifcation_loss: 0.0321 - val_quality_regression_root_mean_squared_error: 0.6414 - val_type_classifcation_accuracy: 0.9937
# Epoch 33/180
# 99/99 [==============================] - 0s 4ms/step - loss: 0.4280 - quality_regression_loss: 0.3957 - type_classifcation_loss: 0.0324 - quality_regression_root_mean_squared_error: 0.6290 - type_classifcation_accuracy: 0.9933 - val_loss: 0.4216 - val_quality_regression_loss: 0.3899 - val_type_classifcation_loss: 0.0318 - val_quality_regression_root_mean_squared_error: 0.6244 - val_type_classifcation_accuracy: 0.9937
# Epoch 34/180
# 99/99 [==============================] - 0s 4ms/step - loss: 0.4182 - quality_regression_loss: 0.3861 - type_classifcation_loss: 0.0320 - quality_regression_root_mean_squared_error: 0.6214 - type_classifcation_accuracy: 0.9937 - val_loss: 0.4145 - val_quality_regression_loss: 0.3832 - val_type_classifcation_loss: 0.0312 - val_quality_regression_root_mean_squared_error: 0.6191 - val_type_classifcation_accuracy: 0.9937
# Epoch 35/180
# 99/99 [==============================] - 0s 4ms/step - loss: 0.4095 - quality_regression_loss: 0.3779 - type_classifcation_loss: 0.0317 - quality_regression_root_mean_squared_error: 0.6147 - type_classifcation_accuracy: 0.9933 - val_loss: 0.4073 - val_quality_regression_loss: 0.3759 - val_type_classifcation_loss: 0.0314 - val_quality_regression_root_mean_squared_error: 0.6131 - val_type_classifcation_accuracy: 0.9924
# Epoch 36/180
# 99/99 [==============================] - 0s 4ms/step - loss: 0.4032 - quality_regression_loss: 0.3718 - type_classifcation_loss: 0.0313 - quality_regression_root_mean_squared_error: 0.6098 - type_classifcation_accuracy: 0.9933 - val_loss: 0.3982 - val_quality_regression_loss: 0.3670 - val_type_classifcation_loss: 0.0312 - val_quality_regression_root_mean_squared_error: 0.6058 - val_type_classifcation_accuracy: 0.9924
# Epoch 37/180
# 99/99 [==============================] - 0s 4ms/step - loss: 0.3967 - quality_regression_loss: 0.3657 - type_classifcation_loss: 0.0309 - quality_regression_root_mean_squared_error: 0.6048 - type_classifcation_accuracy: 0.9937 - val_loss: 0.3920 - val_quality_regression_loss: 0.3610 - val_type_classifcation_loss: 0.0309 - val_quality_regression_root_mean_squared_error: 0.6008 - val_type_classifcation_accuracy: 0.9924
# Epoch 38/180
# 99/99 [==============================] - 0s 4ms/step - loss: 0.3907 - quality_regression_loss: 0.3601 - type_classifcation_loss: 0.0306 - quality_regression_root_mean_squared_error: 0.6001 - type_classifcation_accuracy: 0.9937 - val_loss: 0.3904 - val_quality_regression_loss: 0.3598 - val_type_classifcation_loss: 0.0306 - val_quality_regression_root_mean_squared_error: 0.5999 - val_type_classifcation_accuracy: 0.9937
# Epoch 39/180
# 99/99 [==============================] - 0s 4ms/step - loss: 0.3855 - quality_regression_loss: 0.3552 - type_classifcation_loss: 0.0303 - quality_regression_root_mean_squared_error: 0.5960 - type_classifcation_accuracy: 0.9937 - val_loss: 0.3827 - val_quality_regression_loss: 0.3523 - val_type_classifcation_loss: 0.0303 - val_quality_regression_root_mean_squared_error: 0.5936 - val_type_classifcation_accuracy: 0.9937
# Epoch 40/180
# 99/99 [==============================] - 0s 4ms/step - loss: 0.3807 - quality_regression_loss: 0.3507 - type_classifcation_loss: 0.0301 - quality_regression_root_mean_squared_error: 0.5922 - type_classifcation_accuracy: 0.9937 - val_loss: 0.3826 - val_quality_regression_loss: 0.3522 - val_type_classifcation_loss: 0.0304 - val_quality_regression_root_mean_squared_error: 0.5934 - val_type_classifcation_accuracy: 0.9937
# Epoch 41/180
# 99/99 [==============================] - 0s 4ms/step - loss: 0.3750 - quality_regression_loss: 0.3453 - type_classifcation_loss: 0.0298 - quality_regression_root_mean_squared_error: 0.5876 - type_classifcation_accuracy: 0.9937 - val_loss: 0.3808 - val_quality_regression_loss: 0.3504 - val_type_classifcation_loss: 0.0304 - val_quality_regression_root_mean_squared_error: 0.5919 - val_type_classifcation_accuracy: 0.9937
# Epoch 42/180
# 99/99 [==============================] - 0s 4ms/step - loss: 0.3718 - quality_regression_loss: 0.3423 - type_classifcation_loss: 0.0295 - quality_regression_root_mean_squared_error: 0.5851 - type_classifcation_accuracy: 0.9937 - val_loss: 0.3798 - val_quality_regression_loss: 0.3495 - val_type_classifcation_loss: 0.0302 - val_quality_regression_root_mean_squared_error: 0.5912 - val_type_classifcation_accuracy: 0.9937
# Epoch 43/180
# 99/99 [==============================] - 0s 4ms/step - loss: 0.3697 - quality_regression_loss: 0.3404 - type_classifcation_loss: 0.0292 - quality_regression_root_mean_squared_error: 0.5835 - type_classifcation_accuracy: 0.9940 - val_loss: 0.3755 - val_quality_regression_loss: 0.3454 - val_type_classifcation_loss: 0.0301 - val_quality_regression_root_mean_squared_error: 0.5877 - val_type_classifcation_accuracy: 0.9949
# Epoch 44/180
# 99/99 [==============================] - 0s 4ms/step - loss: 0.3653 - quality_regression_loss: 0.3363 - type_classifcation_loss: 0.0290 - quality_regression_root_mean_squared_error: 0.5799 - type_classifcation_accuracy: 0.9940 - val_loss: 0.3754 - val_quality_regression_loss: 0.3455 - val_type_classifcation_loss: 0.0299 - val_quality_regression_root_mean_squared_error: 0.5878 - val_type_classifcation_accuracy: 0.9949
# Epoch 45/180
# 99/99 [==============================] - 0s 4ms/step - loss: 0.3619 - quality_regression_loss: 0.3331 - type_classifcation_loss: 0.0288 - quality_regression_root_mean_squared_error: 0.5771 - type_classifcation_accuracy: 0.9937 - val_loss: 0.3660 - val_quality_regression_loss: 0.3361 - val_type_classifcation_loss: 0.0298 - val_quality_regression_root_mean_squared_error: 0.5798 - val_type_classifcation_accuracy: 0.9949
# Epoch 46/180
# 99/99 [==============================] - 0s 4ms/step - loss: 0.3597 - quality_regression_loss: 0.3311 - type_classifcation_loss: 0.0285 - quality_regression_root_mean_squared_error: 0.5755 - type_classifcation_accuracy: 0.9940 - val_loss: 0.3663 - val_quality_regression_loss: 0.3367 - val_type_classifcation_loss: 0.0296 - val_quality_regression_root_mean_squared_error: 0.5803 - val_type_classifcation_accuracy: 0.9949
# Epoch 47/180
# 99/99 [==============================] - 0s 4ms/step - loss: 0.3568 - quality_regression_loss: 0.3284 - type_classifcation_loss: 0.0284 - quality_regression_root_mean_squared_error: 0.5730 - type_classifcation_accuracy: 0.9940 - val_loss: 0.3627 - val_quality_regression_loss: 0.3332 - val_type_classifcation_loss: 0.0295 - val_quality_regression_root_mean_squared_error: 0.5773 - val_type_classifcation_accuracy: 0.9949
# Epoch 48/180
# 99/99 [==============================] - 0s 4ms/step - loss: 0.3547 - quality_regression_loss: 0.3265 - type_classifcation_loss: 0.0281 - quality_regression_root_mean_squared_error: 0.5714 - type_classifcation_accuracy: 0.9940 - val_loss: 0.3659 - val_quality_regression_loss: 0.3366 - val_type_classifcation_loss: 0.0293 - val_quality_regression_root_mean_squared_error: 0.5802 - val_type_classifcation_accuracy: 0.9949
# Epoch 49/180
# 99/99 [==============================] - 0s 4ms/step - loss: 0.3524 - quality_regression_loss: 0.3245 - type_classifcation_loss: 0.0279 - quality_regression_root_mean_squared_error: 0.5697 - type_classifcation_accuracy: 0.9946 - val_loss: 0.3723 - val_quality_regression_loss: 0.3430 - val_type_classifcation_loss: 0.0293 - val_quality_regression_root_mean_squared_error: 0.5857 - val_type_classifcation_accuracy: 0.9949
# Epoch 50/180
# 99/99 [==============================] - 0s 4ms/step - loss: 0.3511 - quality_regression_loss: 0.3233 - type_classifcation_loss: 0.0278 - quality_regression_root_mean_squared_error: 0.5686 - type_classifcation_accuracy: 0.9946 - val_loss: 0.3644 - val_quality_regression_loss: 0.3351 - val_type_classifcation_loss: 0.0293 - val_quality_regression_root_mean_squared_error: 0.5789 - val_type_classifcation_accuracy: 0.9949
# Epoch 51/180
# 99/99 [==============================] - 0s 4ms/step - loss: 0.3475 - quality_regression_loss: 0.3199 - type_classifcation_loss: 0.0275 - quality_regression_root_mean_squared_error: 0.5656 - type_classifcation_accuracy: 0.9952 - val_loss: 0.3606 - val_quality_regression_loss: 0.3315 - val_type_classifcation_loss: 0.0291 - val_quality_regression_root_mean_squared_error: 0.5758 - val_type_classifcation_accuracy: 0.9949
# Epoch 52/180
# 99/99 [==============================] - 0s 4ms/step - loss: 0.3466 - quality_regression_loss: 0.3193 - type_classifcation_loss: 0.0274 - quality_regression_root_mean_squared_error: 0.5650 - type_classifcation_accuracy: 0.9946 - val_loss: 0.3606 - val_quality_regression_loss: 0.3316 - val_type_classifcation_loss: 0.0290 - val_quality_regression_root_mean_squared_error: 0.5758 - val_type_classifcation_accuracy: 0.9949
# Epoch 53/180
# 99/99 [==============================] - 0s 4ms/step - loss: 0.3447 - quality_regression_loss: 0.3176 - type_classifcation_loss: 0.0271 - quality_regression_root_mean_squared_error: 0.5635 - type_classifcation_accuracy: 0.9946 - val_loss: 0.3589 - val_quality_regression_loss: 0.3300 - val_type_classifcation_loss: 0.0289 - val_quality_regression_root_mean_squared_error: 0.5744 - val_type_classifcation_accuracy: 0.9949
# Epoch 54/180
# 99/99 [==============================] - 0s 4ms/step - loss: 0.3423 - quality_regression_loss: 0.3153 - type_classifcation_loss: 0.0270 - quality_regression_root_mean_squared_error: 0.5615 - type_classifcation_accuracy: 0.9949 - val_loss: 0.3575 - val_quality_regression_loss: 0.3287 - val_type_classifcation_loss: 0.0288 - val_quality_regression_root_mean_squared_error: 0.5733 - val_type_classifcation_accuracy: 0.9949
# Epoch 55/180
# 99/99 [==============================] - 0s 4ms/step - loss: 0.3409 - quality_regression_loss: 0.3140 - type_classifcation_loss: 0.0269 - quality_regression_root_mean_squared_error: 0.5603 - type_classifcation_accuracy: 0.9949 - val_loss: 0.3532 - val_quality_regression_loss: 0.3245 - val_type_classifcation_loss: 0.0287 - val_quality_regression_root_mean_squared_error: 0.5697 - val_type_classifcation_accuracy: 0.9949
# Epoch 56/180
# 99/99 [==============================] - 0s 4ms/step - loss: 0.3392 - quality_regression_loss: 0.3126 - type_classifcation_loss: 0.0267 - quality_regression_root_mean_squared_error: 0.5591 - type_classifcation_accuracy: 0.9949 - val_loss: 0.3583 - val_quality_regression_loss: 0.3297 - val_type_classifcation_loss: 0.0286 - val_quality_regression_root_mean_squared_error: 0.5742 - val_type_classifcation_accuracy: 0.9949
# Epoch 57/180
# 99/99 [==============================] - 0s 4ms/step - loss: 0.3393 - quality_regression_loss: 0.3128 - type_classifcation_loss: 0.0265 - quality_regression_root_mean_squared_error: 0.5593 - type_classifcation_accuracy: 0.9952 - val_loss: 0.3543 - val_quality_regression_loss: 0.3257 - val_type_classifcation_loss: 0.0286 - val_quality_regression_root_mean_squared_error: 0.5707 - val_type_classifcation_accuracy: 0.9949
# Epoch 58/180
# 99/99 [==============================] - 0s 4ms/step - loss: 0.3368 - quality_regression_loss: 0.3104 - type_classifcation_loss: 0.0264 - quality_regression_root_mean_squared_error: 0.5571 - type_classifcation_accuracy: 0.9952 - val_loss: 0.3555 - val_quality_regression_loss: 0.3269 - val_type_classifcation_loss: 0.0286 - val_quality_regression_root_mean_squared_error: 0.5718 - val_type_classifcation_accuracy: 0.9949
# Epoch 59/180
# 99/99 [==============================] - 0s 4ms/step - loss: 0.3347 - quality_regression_loss: 0.3084 - type_classifcation_loss: 0.0262 - quality_regression_root_mean_squared_error: 0.5554 - type_classifcation_accuracy: 0.9952 - val_loss: 0.3510 - val_quality_regression_loss: 0.3226 - val_type_classifcation_loss: 0.0283 - val_quality_regression_root_mean_squared_error: 0.5680 - val_type_classifcation_accuracy: 0.9949
# Epoch 60/180
# 99/99 [==============================] - 0s 4ms/step - loss: 0.3326 - quality_regression_loss: 0.3065 - type_classifcation_loss: 0.0261 - quality_regression_root_mean_squared_error: 0.5536 - type_classifcation_accuracy: 0.9949 - val_loss: 0.3513 - val_quality_regression_loss: 0.3231 - val_type_classifcation_loss: 0.0282 - val_quality_regression_root_mean_squared_error: 0.5684 - val_type_classifcation_accuracy: 0.9949
# Epoch 61/180
# 99/99 [==============================] - 0s 4ms/step - loss: 0.3330 - quality_regression_loss: 0.3071 - type_classifcation_loss: 0.0259 - quality_regression_root_mean_squared_error: 0.5542 - type_classifcation_accuracy: 0.9956 - val_loss: 0.3586 - val_quality_regression_loss: 0.3304 - val_type_classifcation_loss: 0.0282 - val_quality_regression_root_mean_squared_error: 0.5748 - val_type_classifcation_accuracy: 0.9949
# Epoch 62/180
# 99/99 [==============================] - 0s 4ms/step - loss: 0.3325 - quality_regression_loss: 0.3067 - type_classifcation_loss: 0.0258 - quality_regression_root_mean_squared_error: 0.5538 - type_classifcation_accuracy: 0.9952 - val_loss: 0.3489 - val_quality_regression_loss: 0.3207 - val_type_classifcation_loss: 0.0282 - val_quality_regression_root_mean_squared_error: 0.5663 - val_type_classifcation_accuracy: 0.9949
# Epoch 63/180
# 99/99 [==============================] - 0s 4ms/step - loss: 0.3303 - quality_regression_loss: 0.3047 - type_classifcation_loss: 0.0256 - quality_regression_root_mean_squared_error: 0.5520 - type_classifcation_accuracy: 0.9956 - val_loss: 0.3473 - val_quality_regression_loss: 0.3192 - val_type_classifcation_loss: 0.0281 - val_quality_regression_root_mean_squared_error: 0.5650 - val_type_classifcation_accuracy: 0.9949
# Epoch 64/180
# 99/99 [==============================] - 0s 4ms/step - loss: 0.3291 - quality_regression_loss: 0.3037 - type_classifcation_loss: 0.0254 - quality_regression_root_mean_squared_error: 0.5511 - type_classifcation_accuracy: 0.9956 - val_loss: 0.3492 - val_quality_regression_loss: 0.3211 - val_type_classifcation_loss: 0.0281 - val_quality_regression_root_mean_squared_error: 0.5666 - val_type_classifcation_accuracy: 0.9949
# Epoch 65/180
# 99/99 [==============================] - 0s 4ms/step - loss: 0.3289 - quality_regression_loss: 0.3037 - type_classifcation_loss: 0.0252 - quality_regression_root_mean_squared_error: 0.5511 - type_classifcation_accuracy: 0.9956 - val_loss: 0.3496 - val_quality_regression_loss: 0.3214 - val_type_classifcation_loss: 0.0282 - val_quality_regression_root_mean_squared_error: 0.5670 - val_type_classifcation_accuracy: 0.9949
# Epoch 66/180
# 99/99 [==============================] - 0s 4ms/step - loss: 0.3273 - quality_regression_loss: 0.3021 - type_classifcation_loss: 0.0252 - quality_regression_root_mean_squared_error: 0.5496 - type_classifcation_accuracy: 0.9956 - val_loss: 0.3542 - val_quality_regression_loss: 0.3261 - val_type_classifcation_loss: 0.0281 - val_quality_regression_root_mean_squared_error: 0.5711 - val_type_classifcation_accuracy: 0.9949
# Epoch 67/180
# 99/99 [==============================] - 0s 4ms/step - loss: 0.3259 - quality_regression_loss: 0.3009 - type_classifcation_loss: 0.0250 - quality_regression_root_mean_squared_error: 0.5486 - type_classifcation_accuracy: 0.9956 - val_loss: 0.3489 - val_quality_regression_loss: 0.3211 - val_type_classifcation_loss: 0.0278 - val_quality_regression_root_mean_squared_error: 0.5666 - val_type_classifcation_accuracy: 0.9949
# Epoch 68/180
# 99/99 [==============================] - 0s 4ms/step - loss: 0.3262 - quality_regression_loss: 0.3014 - type_classifcation_loss: 0.0248 - quality_regression_root_mean_squared_error: 0.5490 - type_classifcation_accuracy: 0.9959 - val_loss: 0.3470 - val_quality_regression_loss: 0.3193 - val_type_classifcation_loss: 0.0277 - val_quality_regression_root_mean_squared_error: 0.5651 - val_type_classifcation_accuracy: 0.9949
# Epoch 69/180
# 99/99 [==============================] - 0s 4ms/step - loss: 0.3231 - quality_regression_loss: 0.2985 - type_classifcation_loss: 0.0246 - quality_regression_root_mean_squared_error: 0.5463 - type_classifcation_accuracy: 0.9956 - val_loss: 0.3452 - val_quality_regression_loss: 0.3175 - val_type_classifcation_loss: 0.0277 - val_quality_regression_root_mean_squared_error: 0.5635 - val_type_classifcation_accuracy: 0.9949
# Epoch 70/180
# 99/99 [==============================] - 0s 4ms/step - loss: 0.3239 - quality_regression_loss: 0.2994 - type_classifcation_loss: 0.0245 - quality_regression_root_mean_squared_error: 0.5471 - type_classifcation_accuracy: 0.9959 - val_loss: 0.3473 - val_quality_regression_loss: 0.3198 - val_type_classifcation_loss: 0.0275 - val_quality_regression_root_mean_squared_error: 0.5655 - val_type_classifcation_accuracy: 0.9949
# Epoch 71/180
# 99/99 [==============================] - 0s 4ms/step - loss: 0.3212 - quality_regression_loss: 0.2968 - type_classifcation_loss: 0.0244 - quality_regression_root_mean_squared_error: 0.5448 - type_classifcation_accuracy: 0.9959 - val_loss: 0.3503 - val_quality_regression_loss: 0.3227 - val_type_classifcation_loss: 0.0275 - val_quality_regression_root_mean_squared_error: 0.5681 - val_type_classifcation_accuracy: 0.9949
# Epoch 72/180
# 99/99 [==============================] - 0s 4ms/step - loss: 0.3208 - quality_regression_loss: 0.2965 - type_classifcation_loss: 0.0243 - quality_regression_root_mean_squared_error: 0.5445 - type_classifcation_accuracy: 0.9956 - val_loss: 0.3529 - val_quality_regression_loss: 0.3254 - val_type_classifcation_loss: 0.0275 - val_quality_regression_root_mean_squared_error: 0.5704 - val_type_classifcation_accuracy: 0.9949
# Epoch 73/180
# 99/99 [==============================] - 0s 4ms/step - loss: 0.3201 - quality_regression_loss: 0.2960 - type_classifcation_loss: 0.0241 - quality_regression_root_mean_squared_error: 0.5441 - type_classifcation_accuracy: 0.9959 - val_loss: 0.3439 - val_quality_regression_loss: 0.3166 - val_type_classifcation_loss: 0.0274 - val_quality_regression_root_mean_squared_error: 0.5626 - val_type_classifcation_accuracy: 0.9949
# Epoch 74/180
# 99/99 [==============================] - 0s 4ms/step - loss: 0.3192 - quality_regression_loss: 0.2952 - type_classifcation_loss: 0.0240 - quality_regression_root_mean_squared_error: 0.5433 - type_classifcation_accuracy: 0.9959 - val_loss: 0.3438 - val_quality_regression_loss: 0.3165 - val_type_classifcation_loss: 0.0273 - val_quality_regression_root_mean_squared_error: 0.5625 - val_type_classifcation_accuracy: 0.9949
# Epoch 75/180
# 99/99 [==============================] - 0s 4ms/step - loss: 0.3193 - quality_regression_loss: 0.2954 - type_classifcation_loss: 0.0239 - quality_regression_root_mean_squared_error: 0.5435 - type_classifcation_accuracy: 0.9959 - val_loss: 0.3432 - val_quality_regression_loss: 0.3160 - val_type_classifcation_loss: 0.0272 - val_quality_regression_root_mean_squared_error: 0.5621 - val_type_classifcation_accuracy: 0.9949
# Epoch 76/180
# 99/99 [==============================] - 0s 4ms/step - loss: 0.3182 - quality_regression_loss: 0.2944 - type_classifcation_loss: 0.0238 - quality_regression_root_mean_squared_error: 0.5426 - type_classifcation_accuracy: 0.9959 - val_loss: 0.3421 - val_quality_regression_loss: 0.3150 - val_type_classifcation_loss: 0.0272 - val_quality_regression_root_mean_squared_error: 0.5612 - val_type_classifcation_accuracy: 0.9949
# Epoch 77/180
# 99/99 [==============================] - 0s 4ms/step - loss: 0.3165 - quality_regression_loss: 0.2929 - type_classifcation_loss: 0.0236 - quality_regression_root_mean_squared_error: 0.5412 - type_classifcation_accuracy: 0.9959 - val_loss: 0.3459 - val_quality_regression_loss: 0.3188 - val_type_classifcation_loss: 0.0271 - val_quality_regression_root_mean_squared_error: 0.5646 - val_type_classifcation_accuracy: 0.9949
# Epoch 78/180
# 99/99 [==============================] - 0s 4ms/step - loss: 0.3150 - quality_regression_loss: 0.2914 - type_classifcation_loss: 0.0236 - quality_regression_root_mean_squared_error: 0.5398 - type_classifcation_accuracy: 0.9959 - val_loss: 0.3501 - val_quality_regression_loss: 0.3231 - val_type_classifcation_loss: 0.0271 - val_quality_regression_root_mean_squared_error: 0.5684 - val_type_classifcation_accuracy: 0.9949
# Epoch 79/180
# 99/99 [==============================] - 0s 4ms/step - loss: 0.3157 - quality_regression_loss: 0.2924 - type_classifcation_loss: 0.0233 - quality_regression_root_mean_squared_error: 0.5407 - type_classifcation_accuracy: 0.9959 - val_loss: 0.3471 - val_quality_regression_loss: 0.3201 - val_type_classifcation_loss: 0.0270 - val_quality_regression_root_mean_squared_error: 0.5658 - val_type_classifcation_accuracy: 0.9949
# Epoch 80/180
# 99/99 [==============================] - 0s 4ms/step - loss: 0.3158 - quality_regression_loss: 0.2926 - type_classifcation_loss: 0.0232 - quality_regression_root_mean_squared_error: 0.5409 - type_classifcation_accuracy: 0.9959 - val_loss: 0.3412 - val_quality_regression_loss: 0.3143 - val_type_classifcation_loss: 0.0270 - val_quality_regression_root_mean_squared_error: 0.5606 - val_type_classifcation_accuracy: 0.9949
# Epoch 81/180
# 99/99 [==============================] - 0s 4ms/step - loss: 0.3135 - quality_regression_loss: 0.2904 - type_classifcation_loss: 0.0231 - quality_regression_root_mean_squared_error: 0.5389 - type_classifcation_accuracy: 0.9959 - val_loss: 0.3441 - val_quality_regression_loss: 0.3173 - val_type_classifcation_loss: 0.0269 - val_quality_regression_root_mean_squared_error: 0.5633 - val_type_classifcation_accuracy: 0.9949
# Epoch 82/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.3135 - quality_regression_loss: 0.2905 - type_classifcation_loss: 0.0230 - quality_regression_root_mean_squared_error: 0.5390 - type_classifcation_accuracy: 0.9959 - val_loss: 0.3447 - val_quality_regression_loss: 0.3179 - val_type_classifcation_loss: 0.0268 - val_quality_regression_root_mean_squared_error: 0.5639 - val_type_classifcation_accuracy: 0.9949
# Epoch 83/180
# 99/99 [==============================] - 0s 4ms/step - loss: 0.3123 - quality_regression_loss: 0.2894 - type_classifcation_loss: 0.0229 - quality_regression_root_mean_squared_error: 0.5380 - type_classifcation_accuracy: 0.9959 - val_loss: 0.3448 - val_quality_regression_loss: 0.3181 - val_type_classifcation_loss: 0.0267 - val_quality_regression_root_mean_squared_error: 0.5640 - val_type_classifcation_accuracy: 0.9949
# Epoch 84/180
# 99/99 [==============================] - 0s 4ms/step - loss: 0.3113 - quality_regression_loss: 0.2886 - type_classifcation_loss: 0.0227 - quality_regression_root_mean_squared_error: 0.5372 - type_classifcation_accuracy: 0.9959 - val_loss: 0.3486 - val_quality_regression_loss: 0.3220 - val_type_classifcation_loss: 0.0266 - val_quality_regression_root_mean_squared_error: 0.5675 - val_type_classifcation_accuracy: 0.9949
# Epoch 85/180
# 99/99 [==============================] - 0s 4ms/step - loss: 0.3119 - quality_regression_loss: 0.2893 - type_classifcation_loss: 0.0226 - quality_regression_root_mean_squared_error: 0.5379 - type_classifcation_accuracy: 0.9959 - val_loss: 0.3473 - val_quality_regression_loss: 0.3207 - val_type_classifcation_loss: 0.0266 - val_quality_regression_root_mean_squared_error: 0.5663 - val_type_classifcation_accuracy: 0.9949
# Epoch 86/180
# 99/99 [==============================] - 0s 4ms/step - loss: 0.3110 - quality_regression_loss: 0.2885 - type_classifcation_loss: 0.0225 - quality_regression_root_mean_squared_error: 0.5371 - type_classifcation_accuracy: 0.9959 - val_loss: 0.3430 - val_quality_regression_loss: 0.3165 - val_type_classifcation_loss: 0.0265 - val_quality_regression_root_mean_squared_error: 0.5626 - val_type_classifcation_accuracy: 0.9949
# Epoch 87/180
# 99/99 [==============================] - 0s 4ms/step - loss: 0.3095 - quality_regression_loss: 0.2872 - type_classifcation_loss: 0.0224 - quality_regression_root_mean_squared_error: 0.5359 - type_classifcation_accuracy: 0.9959 - val_loss: 0.3389 - val_quality_regression_loss: 0.3126 - val_type_classifcation_loss: 0.0263 - val_quality_regression_root_mean_squared_error: 0.5591 - val_type_classifcation_accuracy: 0.9949
# Epoch 88/180
# 99/99 [==============================] - 0s 4ms/step - loss: 0.3091 - quality_regression_loss: 0.2869 - type_classifcation_loss: 0.0223 - quality_regression_root_mean_squared_error: 0.5356 - type_classifcation_accuracy: 0.9959 - val_loss: 0.3464 - val_quality_regression_loss: 0.3200 - val_type_classifcation_loss: 0.0264 - val_quality_regression_root_mean_squared_error: 0.5657 - val_type_classifcation_accuracy: 0.9949
# Epoch 89/180
# 99/99 [==============================] - 0s 4ms/step - loss: 0.3087 - quality_regression_loss: 0.2867 - type_classifcation_loss: 0.0220 - quality_regression_root_mean_squared_error: 0.5354 - type_classifcation_accuracy: 0.9959 - val_loss: 0.3450 - val_quality_regression_loss: 0.3189 - val_type_classifcation_loss: 0.0262 - val_quality_regression_root_mean_squared_error: 0.5647 - val_type_classifcation_accuracy: 0.9949
# Epoch 90/180
# 99/99 [==============================] - 0s 4ms/step - loss: 0.3082 - quality_regression_loss: 0.2862 - type_classifcation_loss: 0.0220 - quality_regression_root_mean_squared_error: 0.5350 - type_classifcation_accuracy: 0.9959 - val_loss: 0.3415 - val_quality_regression_loss: 0.3152 - val_type_classifcation_loss: 0.0262 - val_quality_regression_root_mean_squared_error: 0.5615 - val_type_classifcation_accuracy: 0.9949
# Epoch 91/180
# 99/99 [==============================] - 0s 4ms/step - loss: 0.3078 - quality_regression_loss: 0.2859 - type_classifcation_loss: 0.0219 - quality_regression_root_mean_squared_error: 0.5347 - type_classifcation_accuracy: 0.9959 - val_loss: 0.3384 - val_quality_regression_loss: 0.3123 - val_type_classifcation_loss: 0.0261 - val_quality_regression_root_mean_squared_error: 0.5588 - val_type_classifcation_accuracy: 0.9949
# Epoch 92/180
# 99/99 [==============================] - 0s 4ms/step - loss: 0.3074 - quality_regression_loss: 0.2857 - type_classifcation_loss: 0.0217 - quality_regression_root_mean_squared_error: 0.5345 - type_classifcation_accuracy: 0.9959 - val_loss: 0.3441 - val_quality_regression_loss: 0.3179 - val_type_classifcation_loss: 0.0262 - val_quality_regression_root_mean_squared_error: 0.5638 - val_type_classifcation_accuracy: 0.9949
# Epoch 93/180
# 99/99 [==============================] - 0s 4ms/step - loss: 0.3062 - quality_regression_loss: 0.2846 - type_classifcation_loss: 0.0217 - quality_regression_root_mean_squared_error: 0.5335 - type_classifcation_accuracy: 0.9959 - val_loss: 0.3429 - val_quality_regression_loss: 0.3169 - val_type_classifcation_loss: 0.0260 - val_quality_regression_root_mean_squared_error: 0.5629 - val_type_classifcation_accuracy: 0.9949
# Epoch 94/180
# 99/99 [==============================] - 0s 4ms/step - loss: 0.3047 - quality_regression_loss: 0.2831 - type_classifcation_loss: 0.0216 - quality_regression_root_mean_squared_error: 0.5321 - type_classifcation_accuracy: 0.9959 - val_loss: 0.3396 - val_quality_regression_loss: 0.3137 - val_type_classifcation_loss: 0.0259 - val_quality_regression_root_mean_squared_error: 0.5601 - val_type_classifcation_accuracy: 0.9949
# Epoch 95/180
# 99/99 [==============================] - 0s 4ms/step - loss: 0.3048 - quality_regression_loss: 0.2834 - type_classifcation_loss: 0.0214 - quality_regression_root_mean_squared_error: 0.5324 - type_classifcation_accuracy: 0.9959 - val_loss: 0.3449 - val_quality_regression_loss: 0.3190 - val_type_classifcation_loss: 0.0259 - val_quality_regression_root_mean_squared_error: 0.5648 - val_type_classifcation_accuracy: 0.9949
# Epoch 96/180
# 99/99 [==============================] - 0s 4ms/step - loss: 0.3044 - quality_regression_loss: 0.2831 - type_classifcation_loss: 0.0213 - quality_regression_root_mean_squared_error: 0.5321 - type_classifcation_accuracy: 0.9959 - val_loss: 0.3464 - val_quality_regression_loss: 0.3205 - val_type_classifcation_loss: 0.0259 - val_quality_regression_root_mean_squared_error: 0.5662 - val_type_classifcation_accuracy: 0.9949
# Epoch 97/180
# 99/99 [==============================] - 0s 4ms/step - loss: 0.3037 - quality_regression_loss: 0.2825 - type_classifcation_loss: 0.0212 - quality_regression_root_mean_squared_error: 0.5315 - type_classifcation_accuracy: 0.9959 - val_loss: 0.3417 - val_quality_regression_loss: 0.3160 - val_type_classifcation_loss: 0.0257 - val_quality_regression_root_mean_squared_error: 0.5621 - val_type_classifcation_accuracy: 0.9949
# Epoch 98/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.3038 - quality_regression_loss: 0.2827 - type_classifcation_loss: 0.0211 - quality_regression_root_mean_squared_error: 0.5317 - type_classifcation_accuracy: 0.9959 - val_loss: 0.3399 - val_quality_regression_loss: 0.3140 - val_type_classifcation_loss: 0.0258 - val_quality_regression_root_mean_squared_error: 0.5604 - val_type_classifcation_accuracy: 0.9949
# Epoch 99/180
# 99/99 [==============================] - 0s 4ms/step - loss: 0.3028 - quality_regression_loss: 0.2819 - type_classifcation_loss: 0.0210 - quality_regression_root_mean_squared_error: 0.5309 - type_classifcation_accuracy: 0.9959 - val_loss: 0.3389 - val_quality_regression_loss: 0.3130 - val_type_classifcation_loss: 0.0258 - val_quality_regression_root_mean_squared_error: 0.5595 - val_type_classifcation_accuracy: 0.9949
# Epoch 100/180
# 99/99 [==============================] - 0s 4ms/step - loss: 0.3021 - quality_regression_loss: 0.2811 - type_classifcation_loss: 0.0209 - quality_regression_root_mean_squared_error: 0.5302 - type_classifcation_accuracy: 0.9959 - val_loss: 0.3383 - val_quality_regression_loss: 0.3126 - val_type_classifcation_loss: 0.0257 - val_quality_regression_root_mean_squared_error: 0.5591 - val_type_classifcation_accuracy: 0.9949
# Epoch 101/180
# 99/99 [==============================] - 0s 4ms/step - loss: 0.3011 - quality_regression_loss: 0.2803 - type_classifcation_loss: 0.0208 - quality_regression_root_mean_squared_error: 0.5294 - type_classifcation_accuracy: 0.9959 - val_loss: 0.3399 - val_quality_regression_loss: 0.3141 - val_type_classifcation_loss: 0.0258 - val_quality_regression_root_mean_squared_error: 0.5605 - val_type_classifcation_accuracy: 0.9949
# Epoch 102/180
# 99/99 [==============================] - 0s 4ms/step - loss: 0.3008 - quality_regression_loss: 0.2801 - type_classifcation_loss: 0.0207 - quality_regression_root_mean_squared_error: 0.5292 - type_classifcation_accuracy: 0.9959 - val_loss: 0.3377 - val_quality_regression_loss: 0.3122 - val_type_classifcation_loss: 0.0256 - val_quality_regression_root_mean_squared_error: 0.5587 - val_type_classifcation_accuracy: 0.9949
# Epoch 103/180
# 99/99 [==============================] - 0s 4ms/step - loss: 0.3001 - quality_regression_loss: 0.2795 - type_classifcation_loss: 0.0206 - quality_regression_root_mean_squared_error: 0.5287 - type_classifcation_accuracy: 0.9959 - val_loss: 0.3401 - val_quality_regression_loss: 0.3146 - val_type_classifcation_loss: 0.0255 - val_quality_regression_root_mean_squared_error: 0.5609 - val_type_classifcation_accuracy: 0.9949
# Epoch 104/180
# 99/99 [==============================] - 0s 4ms/step - loss: 0.3003 - quality_regression_loss: 0.2798 - type_classifcation_loss: 0.0205 - quality_regression_root_mean_squared_error: 0.5290 - type_classifcation_accuracy: 0.9959 - val_loss: 0.3396 - val_quality_regression_loss: 0.3140 - val_type_classifcation_loss: 0.0256 - val_quality_regression_root_mean_squared_error: 0.5604 - val_type_classifcation_accuracy: 0.9949
# Epoch 105/180
# 99/99 [==============================] - 0s 4ms/step - loss: 0.2985 - quality_regression_loss: 0.2782 - type_classifcation_loss: 0.0204 - quality_regression_root_mean_squared_error: 0.5274 - type_classifcation_accuracy: 0.9959 - val_loss: 0.3444 - val_quality_regression_loss: 0.3189 - val_type_classifcation_loss: 0.0255 - val_quality_regression_root_mean_squared_error: 0.5647 - val_type_classifcation_accuracy: 0.9949
# Epoch 106/180
# 99/99 [==============================] - 0s 4ms/step - loss: 0.2976 - quality_regression_loss: 0.2774 - type_classifcation_loss: 0.0202 - quality_regression_root_mean_squared_error: 0.5267 - type_classifcation_accuracy: 0.9962 - val_loss: 0.3410 - val_quality_regression_loss: 0.3154 - val_type_classifcation_loss: 0.0256 - val_quality_regression_root_mean_squared_error: 0.5616 - val_type_classifcation_accuracy: 0.9949
# Epoch 107/180
# 99/99 [==============================] - 0s 4ms/step - loss: 0.2987 - quality_regression_loss: 0.2785 - type_classifcation_loss: 0.0202 - quality_regression_root_mean_squared_error: 0.5278 - type_classifcation_accuracy: 0.9959 - val_loss: 0.3390 - val_quality_regression_loss: 0.3136 - val_type_classifcation_loss: 0.0254 - val_quality_regression_root_mean_squared_error: 0.5600 - val_type_classifcation_accuracy: 0.9949
# Epoch 108/180
# 99/99 [==============================] - 0s 4ms/step - loss: 0.2976 - quality_regression_loss: 0.2775 - type_classifcation_loss: 0.0201 - quality_regression_root_mean_squared_error: 0.5268 - type_classifcation_accuracy: 0.9962 - val_loss: 0.3382 - val_quality_regression_loss: 0.3128 - val_type_classifcation_loss: 0.0255 - val_quality_regression_root_mean_squared_error: 0.5593 - val_type_classifcation_accuracy: 0.9949
# Epoch 109/180
# 99/99 [==============================] - 0s 4ms/step - loss: 0.2962 - quality_regression_loss: 0.2761 - type_classifcation_loss: 0.0201 - quality_regression_root_mean_squared_error: 0.5255 - type_classifcation_accuracy: 0.9959 - val_loss: 0.3388 - val_quality_regression_loss: 0.3134 - val_type_classifcation_loss: 0.0254 - val_quality_regression_root_mean_squared_error: 0.5598 - val_type_classifcation_accuracy: 0.9949
# Epoch 110/180
# 99/99 [==============================] - 0s 4ms/step - loss: 0.2960 - quality_regression_loss: 0.2760 - type_classifcation_loss: 0.0199 - quality_regression_root_mean_squared_error: 0.5254 - type_classifcation_accuracy: 0.9962 - val_loss: 0.3488 - val_quality_regression_loss: 0.3234 - val_type_classifcation_loss: 0.0254 - val_quality_regression_root_mean_squared_error: 0.5687 - val_type_classifcation_accuracy: 0.9949
# Epoch 111/180
# ...
# Epoch 145/180
# 99/99 [==============================] - 0s 4ms/step - loss: 0.2805 - quality_regression_loss: 0.2634 - type_classifcation_loss: 0.0170 - quality_regression_root_mean_squared_error: 0.5133 - type_classifcation_accuracy: 0.9965 - val_loss: 0.3360 - val_quality_regression_loss: 0.3115 - val_type_classifcation_loss: 0.0245 - val_quality_regression_root_mean_squared_error: 0.5581 - val_type_classifcation_accuracy: 0.9949
# Epoch 146/180
# 99/99 [==============================] - 0s 4ms/step - loss: 0.2787 - quality_regression_loss: 0.2617 - type_classifcation_loss: 0.0170 - quality_regression_root_mean_squared_error: 0.5116 - type_classifcation_accuracy: 0.9965 - val_loss: 0.3424 - val_quality_regression_loss: 0.3178 - val_type_classifcation_loss: 0.0246 - val_quality_regression_root_mean_squared_error: 0.5638 - val_type_classifcation_accuracy: 0.9949
# Epoch 147/180
# 99/99 [==============================] - 0s 4ms/step - loss: 0.2790 - quality_regression_loss: 0.2621 - type_classifcation_loss: 0.0169 - quality_regression_root_mean_squared_error: 0.5120 - type_classifcation_accuracy: 0.9965 - val_loss: 0.3378 - val_quality_regression_loss: 0.3132 - val_type_classifcation_loss: 0.0246 - val_quality_regression_root_mean_squared_error: 0.5596 - val_type_classifcation_accuracy: 0.9949
# Epoch 148/180
# 99/99 [==============================] - 0s 4ms/step - loss: 0.2787 - quality_regression_loss: 0.2619 - type_classifcation_loss: 0.0168 - quality_regression_root_mean_squared_error: 0.5118 - type_classifcation_accuracy: 0.9968 - val_loss: 0.3378 - val_quality_regression_loss: 0.3133 - val_type_classifcation_loss: 0.0245 - val_quality_regression_root_mean_squared_error: 0.5598 - val_type_classifcation_accuracy: 0.9949
# Epoch 149/180
# 99/99 [==============================] - 0s 4ms/step - loss: 0.2777 - quality_regression_loss: 0.2609 - type_classifcation_loss: 0.0167 - quality_regression_root_mean_squared_error: 0.5108 - type_classifcation_accuracy: 0.9968 - val_loss: 0.3388 - val_quality_regression_loss: 0.3143 - val_type_classifcation_loss: 0.0245 - val_quality_regression_root_mean_squared_error: 0.5606 - val_type_classifcation_accuracy: 0.9949
# Epoch 150/180
# 99/99 [==============================] - 0s 4ms/step - loss: 0.2779 - quality_regression_loss: 0.2612 - type_classifcation_loss: 0.0167 - quality_regression_root_mean_squared_error: 0.5111 - type_classifcation_accuracy: 0.9965 - val_loss: 0.3389 - val_quality_regression_loss: 0.3144 - val_type_classifcation_loss: 0.0244 - val_quality_regression_root_mean_squared_error: 0.5607 - val_type_classifcation_accuracy: 0.9949
# Epoch 151/180
# 99/99 [==============================] - 0s 4ms/step - loss: 0.2766 - quality_regression_loss: 0.2600 - type_classifcation_loss: 0.0166 - quality_regression_root_mean_squared_error: 0.5099 - type_classifcation_accuracy: 0.9965 - val_loss: 0.3472 - val_quality_regression_loss: 0.3226 - val_type_classifcation_loss: 0.0246 - val_quality_regression_root_mean_squared_error: 0.5679 - val_type_classifcation_accuracy: 0.9949
# Epoch 152/180
# 99/99 [==============================] - 0s 4ms/step - loss: 0.2773 - quality_regression_loss: 0.2608 - type_classifcation_loss: 0.0165 - quality_regression_root_mean_squared_error: 0.5107 - type_classifcation_accuracy: 0.9968 - val_loss: 0.3352 - val_quality_regression_loss: 0.3108 - val_type_classifcation_loss: 0.0244 - val_quality_regression_root_mean_squared_error: 0.5575 - val_type_classifcation_accuracy: 0.9949
# Epoch 153/180
# 99/99 [==============================] - 0s 4ms/step - loss: 0.2760 - quality_regression_loss: 0.2595 - type_classifcation_loss: 0.0165 - quality_regression_root_mean_squared_error: 0.5094 - type_classifcation_accuracy: 0.9968 - val_loss: 0.3375 - val_quality_regression_loss: 0.3131 - val_type_classifcation_loss: 0.0244 - val_quality_regression_root_mean_squared_error: 0.5595 - val_type_classifcation_accuracy: 0.9949
# Epoch 154/180
# 99/99 [==============================] - 0s 4ms/step - loss: 0.2762 - quality_regression_loss: 0.2598 - type_classifcation_loss: 0.0164 - quality_regression_root_mean_squared_error: 0.5097 - type_classifcation_accuracy: 0.9968 - val_loss: 0.3391 - val_quality_regression_loss: 0.3147 - val_type_classifcation_loss: 0.0243 - val_quality_regression_root_mean_squared_error: 0.5610 - val_type_classifcation_accuracy: 0.9949
# Epoch 155/180
# 99/99 [==============================] - 0s 4ms/step - loss: 0.2756 - quality_regression_loss: 0.2593 - type_classifcation_loss: 0.0163 - quality_regression_root_mean_squared_error: 0.5092 - type_classifcation_accuracy: 0.9965 - val_loss: 0.3371 - val_quality_regression_loss: 0.3126 - val_type_classifcation_loss: 0.0244 - val_quality_regression_root_mean_squared_error: 0.5591 - val_type_classifcation_accuracy: 0.9949
# Epoch 156/180
# 99/99 [==============================] - 0s 4ms/step - loss: 0.2750 - quality_regression_loss: 0.2587 - type_classifcation_loss: 0.0163 - quality_regression_root_mean_squared_error: 0.5087 - type_classifcation_accuracy: 0.9968 - val_loss: 0.3459 - val_quality_regression_loss: 0.3215 - val_type_classifcation_loss: 0.0244 - val_quality_regression_root_mean_squared_error: 0.5670 - val_type_classifcation_accuracy: 0.9949
# Epoch 157/180
# 99/99 [==============================] - 0s 4ms/step - loss: 0.2755 - quality_regression_loss: 0.2593 - type_classifcation_loss: 0.0162 - quality_regression_root_mean_squared_error: 0.5092 - type_classifcation_accuracy: 0.9968 - val_loss: 0.3397 - val_quality_regression_loss: 0.3152 - val_type_classifcation_loss: 0.0244 - val_quality_regression_root_mean_squared_error: 0.5615 - val_type_classifcation_accuracy: 0.9949
# Epoch 158/180
# 99/99 [==============================] - 0s 4ms/step - loss: 0.2739 - quality_regression_loss: 0.2577 - type_classifcation_loss: 0.0162 - quality_regression_root_mean_squared_error: 0.5077 - type_classifcation_accuracy: 0.9968 - val_loss: 0.3365 - val_quality_regression_loss: 0.3122 - val_type_classifcation_loss: 0.0244 - val_quality_regression_root_mean_squared_error: 0.5587 - val_type_classifcation_accuracy: 0.9949
# Epoch 159/180
# 99/99 [==============================] - 0s 4ms/step - loss: 0.2749 - quality_regression_loss: 0.2588 - type_classifcation_loss: 0.0161 - quality_regression_root_mean_squared_error: 0.5087 - type_classifcation_accuracy: 0.9968 - val_loss: 0.3431 - val_quality_regression_loss: 0.3187 - val_type_classifcation_loss: 0.0244 - val_quality_regression_root_mean_squared_error: 0.5645 - val_type_classifcation_accuracy: 0.9949
# Epoch 160/180
# 99/99 [==============================] - 0s 4ms/step - loss: 0.2735 - quality_regression_loss: 0.2574 - type_classifcation_loss: 0.0160 - quality_regression_root_mean_squared_error: 0.5074 - type_classifcation_accuracy: 0.9968 - val_loss: 0.3387 - val_quality_regression_loss: 0.3144 - val_type_classifcation_loss: 0.0243 - val_quality_regression_root_mean_squared_error: 0.5607 - val_type_classifcation_accuracy: 0.9949
# Epoch 161/180
# 99/99 [==============================] - 0s 4ms/step - loss: 0.2738 - quality_regression_loss: 0.2578 - type_classifcation_loss: 0.0160 - quality_regression_root_mean_squared_error: 0.5078 - type_classifcation_accuracy: 0.9968 - val_loss: 0.3361 - val_quality_regression_loss: 0.3116 - val_type_classifcation_loss: 0.0244 - val_quality_regression_root_mean_squared_error: 0.5582 - val_type_classifcation_accuracy: 0.9949
# Epoch 162/180
# 99/99 [==============================] - 0s 4ms/step - loss: 0.2726 - quality_regression_loss: 0.2567 - type_classifcation_loss: 0.0159 - quality_regression_root_mean_squared_error: 0.5066 - type_classifcation_accuracy: 0.9968 - val_loss: 0.3377 - val_quality_regression_loss: 0.3132 - val_type_classifcation_loss: 0.0244 - val_quality_regression_root_mean_squared_error: 0.5597 - val_type_classifcation_accuracy: 0.9949
# Epoch 163/180
# 99/99 [==============================] - 0s 4ms/step - loss: 0.2728 - quality_regression_loss: 0.2569 - type_classifcation_loss: 0.0159 - quality_regression_root_mean_squared_error: 0.5069 - type_classifcation_accuracy: 0.9968 - val_loss: 0.3382 - val_quality_regression_loss: 0.3138 - val_type_classifcation_loss: 0.0244 - val_quality_regression_root_mean_squared_error: 0.5602 - val_type_classifcation_accuracy: 0.9949
# Epoch 164/180
# 99/99 [==============================] - 0s 4ms/step - loss: 0.2718 - quality_regression_loss: 0.2560 - type_classifcation_loss: 0.0158 - quality_regression_root_mean_squared_error: 0.5059 - type_classifcation_accuracy: 0.9968 - val_loss: 0.3376 - val_quality_regression_loss: 0.3131 - val_type_classifcation_loss: 0.0245 - val_quality_regression_root_mean_squared_error: 0.5596 - val_type_classifcation_accuracy: 0.9949
# Epoch 165/180
# 99/99 [==============================] - 0s 4ms/step - loss: 0.2713 - quality_regression_loss: 0.2556 - type_classifcation_loss: 0.0157 - quality_regression_root_mean_squared_error: 0.5056 - type_classifcation_accuracy: 0.9968 - val_loss: 0.3394 - val_quality_regression_loss: 0.3149 - val_type_classifcation_loss: 0.0245 - val_quality_regression_root_mean_squared_error: 0.5611 - val_type_classifcation_accuracy: 0.9949
# Epoch 166/180
# 99/99 [==============================] - 0s 4ms/step - loss: 0.2709 - quality_regression_loss: 0.2552 - type_classifcation_loss: 0.0156 - quality_regression_root_mean_squared_error: 0.5052 - type_classifcation_accuracy: 0.9968 - val_loss: 0.3395 - val_quality_regression_loss: 0.3151 - val_type_classifcation_loss: 0.0244 - val_quality_regression_root_mean_squared_error: 0.5613 - val_type_classifcation_accuracy: 0.9949
# Epoch 167/180
# 99/99 [==============================] - 0s 4ms/step - loss: 0.2707 - quality_regression_loss: 0.2551 - type_classifcation_loss: 0.0156 - quality_regression_root_mean_squared_error: 0.5051 - type_classifcation_accuracy: 0.9968 - val_loss: 0.3424 - val_quality_regression_loss: 0.3180 - val_type_classifcation_loss: 0.0244 - val_quality_regression_root_mean_squared_error: 0.5639 - val_type_classifcation_accuracy: 0.9949
# Epoch 168/180
# 99/99 [==============================] - 0s 4ms/step - loss: 0.2706 - quality_regression_loss: 0.2549 - type_classifcation_loss: 0.0156 - quality_regression_root_mean_squared_error: 0.5049 - type_classifcation_accuracy: 0.9968 - val_loss: 0.3436 - val_quality_regression_loss: 0.3191 - val_type_classifcation_loss: 0.0245 - val_quality_regression_root_mean_squared_error: 0.5649 - val_type_classifcation_accuracy: 0.9949
# Epoch 169/180
# 99/99 [==============================] - 0s 4ms/step - loss: 0.2709 - quality_regression_loss: 0.2554 - type_classifcation_loss: 0.0155 - quality_regression_root_mean_squared_error: 0.5053 - type_classifcation_accuracy: 0.9968 - val_loss: 0.3438 - val_quality_regression_loss: 0.3194 - val_type_classifcation_loss: 0.0244 - val_quality_regression_root_mean_squared_error: 0.5652 - val_type_classifcation_accuracy: 0.9949
# Epoch 170/180
# 99/99 [==============================] - 0s 4ms/step - loss: 0.2695 - quality_regression_loss: 0.2541 - type_classifcation_loss: 0.0153 - quality_regression_root_mean_squared_error: 0.5041 - type_classifcation_accuracy: 0.9968 - val_loss: 0.3350 - val_quality_regression_loss: 0.3107 - val_type_classifcation_loss: 0.0243 - val_quality_regression_root_mean_squared_error: 0.5574 - val_type_classifcation_accuracy: 0.9949
# Epoch 171/180
# 99/99 [==============================] - 0s 4ms/step - loss: 0.2693 - quality_regression_loss: 0.2540 - type_classifcation_loss: 0.0154 - quality_regression_root_mean_squared_error: 0.5039 - type_classifcation_accuracy: 0.9968 - val_loss: 0.3344 - val_quality_regression_loss: 0.3099 - val_type_classifcation_loss: 0.0244 - val_quality_regression_root_mean_squared_error: 0.5567 - val_type_classifcation_accuracy: 0.9949
# Epoch 172/180
# 99/99 [==============================] - 0s 4ms/step - loss: 0.2680 - quality_regression_loss: 0.2527 - type_classifcation_loss: 0.0153 - quality_regression_root_mean_squared_error: 0.5027 - type_classifcation_accuracy: 0.9968 - val_loss: 0.3368 - val_quality_regression_loss: 0.3125 - val_type_classifcation_loss: 0.0243 - val_quality_regression_root_mean_squared_error: 0.5590 - val_type_classifcation_accuracy: 0.9949
# Epoch 173/180
# 99/99 [==============================] - 0s 4ms/step - loss: 0.2691 - quality_regression_loss: 0.2539 - type_classifcation_loss: 0.0152 - quality_regression_root_mean_squared_error: 0.5039 - type_classifcation_accuracy: 0.9968 - val_loss: 0.3376 - val_quality_regression_loss: 0.3131 - val_type_classifcation_loss: 0.0245 - val_quality_regression_root_mean_squared_error: 0.5595 - val_type_classifcation_accuracy: 0.9949
# Epoch 174/180
# 99/99 [==============================] - 0s 4ms/step - loss: 0.2690 - quality_regression_loss: 0.2538 - type_classifcation_loss: 0.0151 - quality_regression_root_mean_squared_error: 0.5038 - type_classifcation_accuracy: 0.9968 - val_loss: 0.3355 - val_quality_regression_loss: 0.3111 - val_type_classifcation_loss: 0.0243 - val_quality_regression_root_mean_squared_error: 0.5578 - val_type_classifcation_accuracy: 0.9949
# Epoch 175/180
# 99/99 [==============================] - 0s 4ms/step - loss: 0.2679 - quality_regression_loss: 0.2528 - type_classifcation_loss: 0.0151 - quality_regression_root_mean_squared_error: 0.5028 - type_classifcation_accuracy: 0.9968 - val_loss: 0.3465 - val_quality_regression_loss: 0.3221 - val_type_classifcation_loss: 0.0245 - val_quality_regression_root_mean_squared_error: 0.5675 - val_type_classifcation_accuracy: 0.9949
# Epoch 176/180
# 99/99 [==============================] - 0s 4ms/step - loss: 0.2674 - quality_regression_loss: 0.2524 - type_classifcation_loss: 0.0150 - quality_regression_root_mean_squared_error: 0.5024 - type_classifcation_accuracy: 0.9968 - val_loss: 0.3420 - val_quality_regression_loss: 0.3176 - val_type_classifcation_loss: 0.0244 - val_quality_regression_root_mean_squared_error: 0.5636 - val_type_classifcation_accuracy: 0.9949
# Epoch 177/180
# 99/99 [==============================] - 0s 4ms/step - loss: 0.2666 - quality_regression_loss: 0.2516 - type_classifcation_loss: 0.0149 - quality_regression_root_mean_squared_error: 0.5016 - type_classifcation_accuracy: 0.9968 - val_loss: 0.3474 - val_quality_regression_loss: 0.3230 - val_type_classifcation_loss: 0.0243 - val_quality_regression_root_mean_squared_error: 0.5683 - val_type_classifcation_accuracy: 0.9949
# Epoch 178/180
# 99/99 [==============================] - 0s 4ms/step - loss: 0.2675 - quality_regression_loss: 0.2526 - type_classifcation_loss: 0.0149 - quality_regression_root_mean_squared_error: 0.5026 - type_classifcation_accuracy: 0.9968 - val_loss: 0.3526 - val_quality_regression_loss: 0.3282 - val_type_classifcation_loss: 0.0243 - val_quality_regression_root_mean_squared_error: 0.5729 - val_type_classifcation_accuracy: 0.9949
# Epoch 179/180
# 99/99 [==============================] - 0s 4ms/step - loss: 0.2668 - quality_regression_loss: 0.2520 - type_classifcation_loss: 0.0148 - quality_regression_root_mean_squared_error: 0.5020 - type_classifcation_accuracy: 0.9968 - val_loss: 0.3368 - val_quality_regression_loss: 0.3124 - val_type_classifcation_loss: 0.0244 - val_quality_regression_root_mean_squared_error: 0.5589 - val_type_classifcation_accuracy: 0.9949
# Epoch 180/180
# 99/99 [==============================] - 0s 4ms/step - loss: 0.2670 - quality_regression_loss: 0.2522 - type_classifcation_loss: 0.0148 - quality_regression_root_mean_squared_error: 0.5021 - type_classifcation_accuracy: 0.9968 - val_loss: 0.3463 - val_quality_regression_loss: 0.3219 - val_type_classifcation_loss: 0.0244 - val_quality_regression_root_mean_squared_error: 0.5674 - val_type_classifcation_accuracy: 0.9949

# %%
loss, quality_loss, type_loss, quality_rmse, type_accuracy = model.evaluate(x=norm_val_X, y=val_Y)

print()
print(f'loss: {loss}')
print(f'quality_loss: {quality_loss}')
print(f'type_loss: {type_loss}')
print(f'quality_rmse: {quality_rmse}')
print(f'type_accuracy: {type_accuracy}')

# EXPECTED VALUES
# ~ 0.30 - 0.38
# ~ 0.30 - 0.38
# ~ 0.018 - 0.030
# ~ 0.50 - 0.62
# ~ 0.97 - 1.0

# Example:
#0.3657050132751465
#0.3463745415210724
#0.019330406561493874
#0.5885359048843384
#0.9974651336669922
# Out:
# 25/25 [==============================] - 0s 3ms/step - loss: 0.3463 - quality_regression_loss: 0.3219 - type_classifcation_loss: 0.0244 - quality_regression_root_mean_squared_error: 0.5674 - type_classifcation_accuracy: 0.9949
#
# loss: 0.3462921380996704
# quality_loss: 0.32190608978271484
# type_loss: 0.02438601292669773
# quality_rmse: 0.567367672920227
# type_accuracy: 0.9949302673339844

# %%
predictions = model.predict(norm_test_X)
quality_pred = predictions[0]
type_pred = predictions[1]

print(quality_pred[0])

# EXPECTED OUTPUT
# 5.6 - 6.0

print(type_pred[0])
print(type_pred[944])

# EXPECTED OUTPUT
# A number close to zero
# A number close to or equal to 1
# Out:
# [5.713019]
# [7.718702e-05]
# [0.9999987]

# %%
def plot_metrics(metric_name, title, ylim=5):
    plt.title(title)
    plt.ylim(0,ylim)
    plt.plot(history.history[metric_name],color='blue',label=metric_name)
    plt.plot(history.history['val_' + metric_name],color='green',label='val_' + metric_name)
    
def plot_confusion_matrix(y_true, y_pred, title='', labels=[0,1]):
    cm = confusion_matrix(y_true, y_pred)
    fig = plt.figure(facecolor='w')
    ax = fig.add_subplot(111)
    cax = ax.matshow(cm)
    plt.title('Confusion matrix of the classifier')
    fig.colorbar(cax)
    ax.set_xticklabels([''] + labels)
    ax.set_yticklabels([''] + labels)
    plt.xlabel('Predicted')
    plt.ylabel('True')
    
    fmt = 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
          plt.text(j, i, format(cm[i, j], fmt),
                  horizontalalignment="center",
                  color="black" if cm[i, j] > thresh else "white")

def plot_diff(y_true, y_pred, title = '' ):
    plt.scatter(y_true, y_pred)
    plt.title(title)
    plt.xlabel('True Values')
    plt.ylabel('Predictions')
    plt.axis('equal')
    plt.axis('square')
    plt.plot([-100, 100], [-100, 100])
    return plt

# %%
plot_metrics('quality_regression_root_mean_squared_error', 'RMSE', ylim=2)
# history.history.keys()

# %%
plot_metrics('type_classifcation_loss', ' Type Loss', ylim=0.2)

# %%
plot_confusion_matrix(test_Y[1], np.round(type_pred), title='Type', labels = [0, 1])
# Out:
# /home/mo/.local/lib/python3.6/site-packages/ipykernel_launcher.py:14: UserWarning: FixedFormatter should only be used together with FixedLocator
#
# /home/mo/.local/lib/python3.6/site-packages/ipykernel_launcher.py:15: UserWarning: FixedFormatter should only be used together with FixedLocator
#   from ipykernel import kernelapp as app

# %%
scatter_plot = plot_diff(test_Y[0], quality_pred, title='Type')
